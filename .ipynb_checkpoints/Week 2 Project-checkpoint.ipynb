# %% [markdown]
# # Project Description
#
# In this project, we create a scraper program that visits the e-commerce website TIKI at https://tiki.vn, reads its categories & products content, extracts the information and insert into our Portgres database.
#
# The main function of our scapper is to collect the product information of products being sold on Tiki, including products on every pages of all categories. The collected information will be saved as arrays, which will in turn be added into a Pandas dataframe.
#
# The product information includes:
#
#     * Product ID
#     * Seller ID
#     * Category ID
#     * Product title
#     * URL of the product image
#     * Price (Regular and Final)
#     * Tiki Now service
#     * Product URL
#     * Rating
#     * Number of reviews
#
#
# ### Database Diagram
# ![DB Diagram](https://i.imgur.com/15PXEXj.jpg)

# %% [markdown]
# ## Import libraries

# %%
# Import libraries
import pandas as pd
import datetime
import requests
from bs4 import BeautifulSoup
import psycopg2
import logging
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Adding some global variables
#
# #### Note on the table prefix
# We define a prefix for our table for two reasons:
# 1. We use the prefix for our select_from_db() function
# 2. As a best practice, using a prefix make the software more scalable, i.e. You can store the tables of this program into the same database with other programs.

# %%
# Define constants and table prefix
tbl_prefix = "tiki_"
SCRAPING_URL = "https://tiki.vn"

# %% [markdown]
# ## Connect to the Database

# %%
def print_exception(err):
	"""
	This function is used to render the Exception error
	"""
	logging.exception(err)

def connect_to_db():
	""" This function returns a database connection
	"""
	try:
		connection = psycopg2.connect(user = "duong",
										password = 'P@ssw0rd',
										host = "127.0.0.1",
										port = "5432",
										database = "fansipan_week2")
		return connection

	except (Exception, psycopg2.Error) as err:
		print_exception(err)

# %% [markdown]
# ## Create Database Tables

# %%
def create_db_table__categories():
	""" This function will create the database table tiki_categories
	"""
	try:
		# Connect to the database and create a cursor
		conn = connect_to_db()
		cursor = conn.cursor()
		
		# Create the SQL query
		sql = 	"CREATE TABLE IF NOT EXISTS " + tbl_prefix + "categories \
				(cat_id SERIAL NOT NULL PRIMARY KEY, \
				cat_name text NOT NULL, \
				cat_url text NOT NULL)"

		# Execute the query
		cursor.execute(sql)

		# Commit the changes made to the database
		conn.commit()

	except (Exception, psycopg2.Error) as err:
		print_exception(err)
		# In case of error, cancel all changes made to our database during the connection
		conn.rollback()

	finally:
		# Close database connection
		cursor.close()
		conn.close()

def create_db_table__products():
	""" This function will create the database table tiki_products
	"""
	try:
		# Connect to the database and create a cursor
		conn = connect_to_db()
		cursor = conn.cursor()
		
		# Create the SQL query
		# Note: because not all products return all prices, so to prevent error in the inserting process,
		# we decide to use varchar as the data type for prices and convert data type for further use
		sql = 	"CREATE TABLE IF NOT EXISTS " + tbl_prefix + "products \
				(product_id integer NOT NULL PRIMARY KEY, \
				seller_id integer NOT NULL, \
				cat_id integer NOT NULL REFERENCES " + tbl_prefix + "categories(cat_id), \
				title text NOT NULL, \
				image_url text, \
				price_regular integer, \
				price_final integer, \
				rating float, \
				tiki_now boolean, \
				product_url text NOT NULL, \
				review_total integer, \
				insert_date timestamp)"

		# Execute the query
		cursor.execute(sql)

		# Commit the changes made to the database
		conn.commit()

	except (Exception, psycopg2.Error) as err:
		print_exception(err)
		# In case of error, cancel all changes made to our database during the connection
		conn.rollback()

	finally:
		# Close database connection
		cursor.close()
		conn.close()

# %% [markdown]
# ## The Scraper
#
# The scraper will parse the product page from the given URL and return a list of products. If there is no products, it will return an empty list.

# %%
# Parser function to retrieve and parse the HTML code of a website 
def parser(url):
	"""Get a parsed version of an URL"""

	try:
		# Retrieve plain HTML code
		plain = requests.get(url).text

		# Parse the plain content into structured one
		soup = BeautifulSoup(plain, features="lxml")

		return soup

	except Exception as err:
		print_exception(err)

def scrape_products(cat_id, cat_name, url):
	"""Scrape product information of all products on one page"""

	try:
		# Initialize empty 'results' list
		results = []

		# Get the parsed html code
		soup = parser(url)

		# Find all products on this page
		product_items = soup.find_all('div', class_='product-item')

		# If there is no products, return an empty list.
		if len(product_items) == 0:
			return []
		
		# If the page has products
		else: 
      		
			# Set default values for some variables
			rating = -1
			tiki_now = ''
			product_url = ''
			review_total = 0

			# Iterate through all product_items and store the product information in the 'row' list
			for product in product_items:
				
        		# Extract the rating value
				if len(product.select('.rating-content > span')) > 0:
					rating = product.select_one('.rating-content > span')["style"]
					rating = rating.replace('width:', '').replace('%', '')
				
        		# Extract the number of reviews value
				if len(product.select('.review-wrap .review')) > 0:
					review_total = product.select_one('.review-wrap .review').string
					review_total = review_total[review_total.find('(')+1:review_total.find(' ')]

				# Extract the regular price
				price_regular = product.find('span', class_="price-regular").text
				if price_regular != '':
					price_regular = price_regular[0:-2].replace('.', '')
				else:
					price_regular = -1

				# Extract the final price
				price_final = product.get('data-price')
				if price_final == '' or price_final == None:
						price_final = -1

				# Extract the Tiki Now value
				tiki_now = True if len(product.select('i.icon-tikinow')) > 0 else False

				# Extract the product url
				product_url = product.select_one('a')['href']

				# Add the insert to db date
				insert_date = datetime.datetime.now()

				row = 	{	'product_id' : product.get('data-id'), 
							'seller_id' : product.get('data-seller-product-id'),
							'cat_id' : cat_id,
							'title' : product.get('data-title'),
							'image_url' : product.img['src'],
							'price_regular' : price_regular,
							'price_final' : price_final,
							'rating' : rating,
							'tiki_now' : tiki_now,
							'product_url' : product_url,
							'review_total' : review_total,
							'insert_date' : insert_date
						}

				# Add the product information of each product into the 'results' list
				results.append(row)

		return results
	except Exception as err:
		print_exception(err)

# %% [markdown]
# ## Insert into the database
#
# We inserted both the categories and products information into our database.
#
# ### Prevent product duplication
#
# We discovered that some products are repeatedly displayed on Tiki's products pages, so we need to check for the duplication before inserting any product into our database.
#
# The function will first check if the current product is existed in the database or not.
#     * If the current product is existed, the function will skip it.
#     * If the current product is not existed, the function will insert it into the database.

# %%
def insert_to_db__categories():
	""" Get the URLs of all categories information on Tiki.vn
		and store the data into our database
	"""
	try:
		# Get the homepage's html in BeautifulSoup format
		soup = parser(SCRAPING_URL)

		# Connect to the database and create a cursor
		conn = connect_to_db()
		cursor = conn.cursor()
		
		# Scrape through the main category navigation bar
		for i in soup.find_all('li', class_="MenuItem-tii3xq-0"):
			
			# Get the category value
			category = i.a.find('span', class_='text').text
			
			# Get the url value
			url = i.a["href"]

			# Build the SQL query with our data
			data = {"cat_name" : category, "cat_url" : url}
			
			# Check for existed category in the database
			sql =  "SELECT 1 FROM " + tbl_prefix + "categories \
					WHERE cat_url = \'" + data['cat_url'] + "\'"
			cursor.execute(sql)

			# If there is no existed category in the databse, then insert 
			if cursor.fetchone() is None:
				# Create our SQL query
				sql = "INSERT INTO " + tbl_prefix + "categories (cat_name, cat_url)\
						VALUES(%(cat_name)s, %(cat_url)s)"

				# Execute the query
				cursor.execute(sql, data)

				# Commit to insert data into the database
				conn.commit()

	except (Exception, psycopg2.Error) as err:
		print_exception(err)
		# In case of error, cancel all changes made to our database during the connection
		conn.rollback()
	
	finally:
		# Close the database connection
		cursor.close()
		conn.close()

def insert_to_db__products():
	""" Get the URLs of all products information on Tiki.vn
		and insert the data into our database on table tiki_products
	"""
	try:
		# Connect to the database and create a cursor
		conn = connect_to_db()
		cursor = conn.cursor()
		
		# Get all category links from tiki_categories table in the database
		queue = select_from_db(tbl_prefix + "categories")

		# Initialize the 'page' variable, which indicates the current product page of the current category
		page = 1

		# While there are links in the queue, we will run through each link and get the products
		while len(queue) > 0:

			# We will proceed from the last link in the queue     
			cat_id = queue[-1][0]
			cat_name = queue[-1][1]
			url = queue[-1][2]

			# Check to keep the original category's url and its category name
			if "page" not in url:
				url_orig = url
				cat_id_orig = cat_id
				cat_name_orig = cat_name
				
			# Remove the last link in queue so that new product url from page 2 will be added at the end of the queue
			queue.pop() 
			
			print('Scraping', cat_name_orig + " page " + str(page))
			print(url)
			
			# Get the list of products of the current page and store it in a temporary variable
			list_current_products = scrape_products(cat_id, cat_name, url)
			
			# If the page has products, we will create the next product page link and add it to the queue
			if len(list_current_products) > 0:

				# Generate next page url and add it to the end of list `queue` so that it will be the next link to be scraped
				page += 1
				url = url_orig + "&page=" + str(page)

				print('Insert to db\n')
				for product in list_current_products:
					
					# Check for existed products in the database
					sql =  "SELECT 1 FROM " + tbl_prefix + "products \
							WHERE product_id = " + product['product_id']
					cursor.execute(sql)
					
					# If there is no existed product in the databse, then insert 
					if cursor.fetchone() is None:

						# Create our SQL query
						sql = "INSERT INTO " + tbl_prefix + "products \
								VALUES (%(product_id)s, %(seller_id)s, %(cat_id)s, %(title)s, \
										%(image_url)s, %(price_regular)s, %(price_final)s, %(rating)s, \
										%(tiki_now)s, %(product_url)s, %(review_total)s, %(insert_date)s)"

						# Execute the query to insert a product to the database
						cursor.execute(sql, product)
						conn.commit()

				# Add the new page url to the end of list `queue`
				queue.append([cat_id_orig, cat_name_orig, url]) 
					
				print('Add next page', page)
			else: 
				# Now the product page link doesn't return any product, which indicates that we have done getting all products...
				# ...of the current category. We will reset the page number to 1 in order to scrape the next category
				page = 1

	except (Exception, psycopg2.Error) as err:
		print_exception(err)

		# In case of error, cancel all changes made to our database during the connection
		conn.rollback()
	
	finally:
		# Close the database connection
		cursor.close()
		conn.close()

# %% [markdown]
# ## Select Data From the Database
#
# We made our function a bit more handy by allowing it to do two features:
# 1. If the input is a table name, it will return a list of all rows from that table
# 2. If the input is a SQL query, it will execute that query and return the desire results

# %%
def select_from_db(sql):
	"""
	This function will execute the SELECT query and return the list of results
	1. If the input is a table name, it will return a list of all rows from that table
	2. If the input is a SQL query, it will execute that query and return the desire results
	"""
	try:
		
		#Create an empty list
		list_results = []

		# Connect to the database
		conn = connect_to_db()

		# Create a cursor
		cursor = conn.cursor()

		# Get data from the database
		# If the input variable starts with the table prefix, then this is the standard SELECT query
		# Otherwise, we will use the input value as the query
		if sql.startswith(tbl_prefix):
			sql = "SELECT * FROM " + sql
	
		cursor.execute(sql)

		list_results = cursor.fetchall()

		return list_results

	except (Exception, psycopg2.Error) as err:
		print_exception(err)
		conn.rollback()

	finally:
		# Close the database connection
		cursor.close()
		conn.close()

# %% [markdown]
# ## Execute the program

# %%
# Create necessary database tables
create_db_table__categories()
create_db_table__products()

# scrape all categories from tiki.vn and insert into the database
insert_to_db__categories()

# scrape all products from tiki.vn and insert into the database
insert_to_db__products()

# %% [markdown]
# # Data Analysis

# %% [markdown]
# ### The DataFrame

# %%
# Create the DataFrame
query = "SELECT p.product_id, p.seller_id, p.cat_id, c.cat_name, p.title, p.image_url, p.price_regular, p.price_final, p.rating, p.review_total, p.tiki_now, p.product_url, p.insert_date \
         FROM " + tbl_prefix + "products AS p \
         LEFT JOIN " + tbl_prefix + "categories AS c \
         ON p.cat_id = c.cat_id \
         ORDER BY p.insert_date ASC"
products_all = select_from_db(query)

df = pd.DataFrame(products_all, columns = ['product_id', 
                                       'seller_id', 
                                       'cat_id',
                                       'cat_name',
                                       'title', 
                                       'image_url', 
                                       'price_regular',
                                       'price_final',
                                       'rating',
                                       'review_total',
                                       'tiki_now',
                                       'product_url',
                                       'insert_date'])

df.sample(5)
# Out:
#         product_id  seller_id  cat_id  \
# 120081    15123553   15123554       3
# 51376      9672916    9672918      11
# 4015       4040663    6329957      15
# 6192        595724     595727      15
# 77864     13171534   13171536       8
#
#                                                  cat_name  \
# 120081  Phụ Kiện - Thiết Bị Số (Accessories - Digital ...
# 51376       Thời trang - Phụ kiện (Fashion - Accessories)
# 4015         Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 6192         Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 77864   Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
#
#                                                     title  \
# 120081  Ốp lưng dẻo cho điện thoại Huawei P30 Lite - 0...
# 51376          Túi Vải Đeo Chéo Tote Bag Living XinhStore
# 4015    25 Chuyên Đề Ngữ Pháp Tiếng Anh Trọng Tâm – (T...
# 6192               Giáo Trình Chuẩn HSK 4 Bài Học (Tập 1)
# 77864                                Trà Hạt Chia Mộc Sắc
#
# ...

# %%
df.describe()
# Out:
#          product_id     seller_id         cat_id  price_regular   price_final  \
# count  1.381330e+05  1.381330e+05  138133.000000   1.381330e+05  1.381330e+05
# mean   9.505027e+06  1.119445e+07       8.995454   1.778616e+06  1.958117e+06
# std    6.942771e+06  7.266146e+06       4.122258   9.357948e+06  1.030429e+07
# min    4.138200e+04  3.600000e+01       1.000000  -1.000000e+00 -1.000000e+00
# 25%    2.780549e+06  4.263061e+06       5.000000   6.400000e+04  9.900000e+04
# 50%    9.159753e+06  1.142780e+07       9.000000   2.180000e+05  2.140000e+05
# 75%    1.485813e+07  1.675592e+07      13.000000   6.200000e+05  6.990000e+05
# max    2.442504e+07  2.459595e+07      16.000000   6.900000e+08  6.490000e+08
#
#               rating   review_total
# count  138133.000000  138133.000000
# mean       44.774927       4.058458
# std        41.180747      25.296124
# min        -1.000000       0.000000
# 25%        -1.000000       0.000000
# 50%        60.000000       1.000000
# ...

# %% [markdown]
# ### The total number of scraped products

# %%
total_products = len(products_all)
print("The total number of scraped products is:", total_products)
# Out:
# The total number of scraped products is: 138133

# %% [markdown]
# ### Product Counts by category

# %%
# Group products count by category name
df_products_by_category = df.groupby("cat_name").agg({'cat_name':{'total_products': 'count'}})

# Cut off the first column labels
df_products_by_category.columns = df_products_by_category.columns.droplevel(0)

# Calculate the percentage of each category's products count
df_products_by_category['percentage'] = round(df_products_by_category['total_products']/total_products*100, 1)

# Visualize data in bar chart
sns.set(style="whitegrid")
sns.countplot(y="cat_name", data=df, palette="Set2")

df_products_by_category.sort_values("total_products", ascending=False)
# Out:
#                                                     total_products  percentage
# cat_name
# Phụ Kiện - Thiết Bị Số (Accessories - Digital D...           15270        11.1
# Hàng quốc tế (International Goods)                           10686         7.7
# Sách, VPP & Quà Tặng (Books, Office & Gifts)                 10061         7.3
# Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicycles)            9960         7.2
# Thể Thao - Dã Ngoại (Sports - Outdoors)                       9957         7.2
# Đồ chơi, Mẹ & Bé (Toys, Mums & Baby)                          9894         7.2
# Làm Đẹp - Sức Khỏe (Beauty - Healthcare)                      9833         7.1
# Nhà Cửa Đời Sống (Housing Products)                           9773         7.1
# Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - Fo...            9672         7.0
# Thời trang - Phụ kiện (Fashion - Accessories)                 9660         7.0
# Điện Gia Dụng (Electric Appliances)                           9508         6.9
# ...

# %% [markdown]
# ### Rated Products

# %%
total_rated_products = len(df[df["rating"] > -1])
total_rated_products_percent = round((total_rated_products/total_products)*100, 1)
print("The number of products with user ratings:", total_rated_products)
print("The percentage of products with user ratings: {}%".format(total_rated_products_percent))

# Visualize data in Pie chart
labels = ["Products without ratings", "Products with ratings"]
product_types = (df["rating"] > -1).value_counts().sort_index()

f, ax1 = plt.subplots()
ax1.pie(product_types, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# The number of products with user ratings: 81192
# The percentage of products with user ratings: 58.8%

# %% [markdown]
# ### The hottest product

# %%
df[df["review_total"] == df["review_total"].max()][["product_id", 
                                                    "cat_name",
                                                    "title",
                                                    "price_final", 
                                                    "rating", 
                                                    "review_total",
                                                    "tiki_now"]]
# Out:
#       product_id                                      cat_name        title  \
# 3558      378448  Sách, VPP & Quà Tặng (Books, Office & Gifts)  Nhà Giả Kim
#
#       price_final  rating  review_total  tiki_now
# 3558        44850    93.0          3436      True

# %% [markdown]
# ### Top 10 hottest products

# %%
df_hottest_products = df[df["review_total"] > 0][["product_id", 
                                                  "cat_name",
                                                  "title",
                                                  "price_final", 
                                                  "rating", 
                                                  "review_total",
                                                  "tiki_now"]]

df_hottest_products.sort_values('review_total', ascending=False).head(10)
# Out:
#         product_id                                      cat_name  \
# 3558        378448  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3577        551563  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3576        617397  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3610        418676  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3566        480040  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3713        335337  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3629        435425  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3640        415412  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 3641      21047079  Sách, VPP & Quà Tặng (Books, Office & Gifts)
# 125661     1929161   Điện Thoại - Máy Tính Bảng (Phone - Tablet)
#
#                                                     title  price_final  \
# 3558                                          Nhà Giả Kim        44850
# 3577                          Tuổi Trẻ Đáng Giá Bao Nhiêu        63900
# ...

# %% [markdown]
# ### Hottest categories

# %%
# Group the categories by number of total review
df_hottest_cat = df[df["review_total"] > 0].groupby(["cat_id", "cat_name"])[["review_total"]].sum()
total_reviews = df_hottest_cat["review_total"].sum()

# Get percentage
df_hottest_cat['percentage'] = round((df_hottest_cat["review_total"]/total_reviews)*100, 1)

# sort the data 
df_hottest_cat.sort_values("review_total", ascending=False)
# Out:
#                                                            review_total  \
# cat_id cat_name
# 15     Sách, VPP & Quà Tặng (Books, Office & Gifts)              177908
# 10     Làm Đẹp - Sức Khỏe (Beauty - Healthcare)                   80622
# 3      Phụ Kiện - Thiết Bị Số (Accessories - Digital D...         49907
# 7      Nhà Cửa Đời Sống (Housing Products)                        43259
# 11     Thời trang - Phụ kiện (Fashion - Accessories)              36869
# 9      Đồ chơi, Mẹ & Bé (Toys, Mums & Baby)                       30880
# 6      Điện Gia Dụng (Electric Appliances)                        26119
# 8      Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - Fo...         25008
# 4      Laptop - Thiết bị IT (Laptop - IT Equipments)              24171
# 12     Thể Thao - Dã Ngoại (Sports - Outdoors)                    20896
# 1      Điện Thoại - Máy Tính Bảng (Phone - Tablet)                10991
# 5      Máy Ảnh - Quay Phim (Digital Cameras)                       9070
# ...

# %% [markdown]
# ### How many products having TikiNow service?

# %%
total_tikinow_products = len(df[df["tiki_now"] == True])
total_tikinow_products_percent = round((total_tikinow_products/total_products)*100, 1)

print("Total products with TikiNow:", total_tikinow_products)
print("The percentage of TikiNow products: {}%".format(total_tikinow_products_percent))

# Visualize data in Pie chart
labels = ["No TikiNow", "tikiNow"]
product_types = df['tiki_now'].value_counts().sort_index()

f, ax1 = plt.subplots()
ax1.pie(product_types, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
# Out:
# Total products with TikiNow: 40577
# The percentage of TikiNow products: 29.4%

# %% [markdown]
# ### Which category has the most products with TikiNow?

# %%
df_cat_with_tikinow = df[df["tiki_now"] == True].groupby('cat_name').agg({"product_id":{"total_products":"count"}})

# Cut off the first column labels
df_cat_with_tikinow.columns = df_cat_with_tikinow.columns.droplevel(0)

# Drop the column percentage from df_products_by_category
df_products_by_category_1 = df_products_by_category.drop(columns='percentage')

# Order descendingly
df_cat_with_tikinow.sort_values("total_products", ascending=False)

# Merge the two data frame
df_cat_with_tikinow = pd.merge(df_products_by_category_1, df_cat_with_tikinow, how="left", on="cat_name")

# Order descendingly
df_cat_with_tikinow = df_cat_with_tikinow.sort_values("total_products_y", ascending=False)

# Get the percentage of products with tikiNow vs all products in each category
df_cat_with_tikinow["percentage"] = round(df_cat_with_tikinow["total_products_y"]/df_cat_with_tikinow["total_products_x"]*100, 2)

# Rename the columns
df_cat_with_tikinow.rename(columns = {'total_products_x': 'total_products',
                                               'total_products_y': 'total_products_with_tikinow'})
# Out:
#                                                     total_products  \
# cat_name
# Sách, VPP & Quà Tặng (Books, Office & Gifts)                 10061
# Làm Đẹp - Sức Khỏe (Beauty - Healthcare)                      9833
# Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - Fo...            9672
# Đồ chơi, Mẹ & Bé (Toys, Mums & Baby)                          9894
# Nhà Cửa Đời Sống (Housing Products)                           9773
# Thời trang - Phụ kiện (Fashion - Accessories)                 9660
# Phụ Kiện - Thiết Bị Số (Accessories - Digital D...           15270
# Điện Gia Dụng (Electric Appliances)                           9508
# Thể Thao - Dã Ngoại (Sports - Outdoors)                       9957
# Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicycles)            9960
# Laptop - Thiết bị IT (Laptop - IT Equipments)                 9405
# Máy Ảnh - Quay Phim (Digital Cameras)                         8929
# Điện Thoại - Máy Tính Bảng (Phone - Tablet)                    947
# ...

# %% [markdown]
# ### Top 10 most expensive products on Tiki

# %%
df.sort_values("price_final", ascending=False).head(10)[["product_id",
                                                        "cat_name",
                                                        "title", 
                                                        "price_final", 
                                                        "rating", 
                                                        "review_total",
                                                        "tiki_now"]]
# Out:
#         product_id                                           cat_name  \
# 25043     21856456  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 26096     15085097  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 26098     15085101  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 26099     15085099  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 25044     21856322  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 26095     21856397  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 29290     15085123  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 26097     15085103  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
# 121407     2172085  Phụ Kiện - Thiết Bị Số (Accessories - Digital ...
# 27895     15085183  Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicyc...
#
#                                                     title  price_final  \
# 25043                   Xe Môtô Triumph Scrambler 1200 XE    649000000
# ...

# %% [markdown]
# ### And Now...The cheapest products are...

# %%
df[df["price_final"] > 0].sort_values("price_final", ascending=True).head(10)[["product_id",
                                                                            "cat_name",
                                                                            "title", 
                                                                            "price_final", 
                                                                            "rating", 
                                                                            "review_total",
                                                                            "tiki_now", ]]
# Out:
#         product_id                                           cat_name  \
# 130460    14436550  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 79697     14608347  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 71121     14608408  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 70833     14608349  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 77818     14608358  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 130461    14608378  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 73364     14608352  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 70759     17604188  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 70937     14436554  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
# 76883      7668021  Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - F...
#
#                                               title  price_final  rating  \
# 130460                     Muối Hạt Bạc Liêu (500g)         2933    95.0
# ...

# %% [markdown]
# ### Most valuable category

# %%
# Group products value by category
df_category_value = df.groupby("cat_name").agg({'product_id':{'total_products': 'count'},
                                                'price_final':{'cat_value': 'sum'}})
# Cut off the first column labels
df_category_value.columns = df_category_value.columns.droplevel(0)

# Get total value of all products on Tiki
total_tiki_product_value = df_category_value['cat_value'].sum()

# Calculate the percentage of product value
df_category_value['cat_value_percentage'] = round(df_category_value['cat_value']/total_tiki_product_value*100, 1)
df_category_value.sort_values('cat_value', ascending=False)
# Out:
#                                                     total_products  \
# cat_name
# Xe Máy, Ô tô, Xe Đạp (Motorcycles, Cars, Bicycles)            9960
# Phụ Kiện - Thiết Bị Số (Accessories - Digital D...           15270
# Laptop - Thiết bị IT (Laptop - IT Equipments)                 9405
# Điện Gia Dụng (Electric Appliances)                           9508
# Máy Ảnh - Quay Phim (Digital Cameras)                         8929
# Thể Thao - Dã Ngoại (Sports - Outdoors)                       9957
# Voucher - Dịch Vụ - Thẻ Cào (Vouchers - Service...            4578
# Hàng quốc tế (International Goods)                           10686
# Điện Thoại - Máy Tính Bảng (Phone - Tablet)                    947
# Đồ chơi, Mẹ & Bé (Toys, Mums & Baby)                          9894
# Nhà Cửa Đời Sống (Housing Products)                           9773
# Thời trang - Phụ kiện (Fashion - Accessories)                 9660
# Làm Đẹp - Sức Khỏe (Beauty - Healthcare)                      9833
# ...

# %% [markdown]
# ### Why you should go shopping on Tiki?
#
# Compare to the product's market price, here is how much money you will save by shopping on Tiki!

# %%
# Group category by product's price, only get product with price_regular > 0
df_category_prices = df[df["price_regular"] > 0].groupby("cat_name").agg({'price_regular':{'market_price_total': 'sum'},
                                             'price_final':{'tiki_price_total': 'sum'}})

# Cut off the first column labels
df_category_prices.columns = df_category_prices.columns.droplevel(0)

# Calculate the amount of money saved  
df_category_prices["saving_value"] = df_category_prices["market_price_total"] - df_category_prices["tiki_price_total"]

# Calculate the percentage of saving money
df_category_prices["saving_percentage"] = round(df_category_prices["saving_value"]/df_category_prices["market_price_total"]*100, 1)

# Order Descendingly
df_category_prices.sort_values('saving_percentage', ascending=False)
# Out:
#                                                     market_price_total  \
# cat_name
# Thời trang - Phụ kiện (Fashion - Accessories)               3905866969
# Nhà Cửa Đời Sống (Housing Products)                         4531190608
# Làm Đẹp - Sức Khỏe (Beauty - Healthcare)                    3173295992
# Sách, VPP & Quà Tặng (Books, Office & Gifts)                1150823100
# Voucher - Dịch Vụ - Thẻ Cào (Vouchers - Service...          6826648128
# Hàng quốc tế (International Goods)                          2736688187
# Đồ chơi, Mẹ & Bé (Toys, Mums & Baby)                        3161162048
# Thể Thao - Dã Ngoại (Sports - Outdoors)                     6539495452
# Điện Gia Dụng (Electric Appliances)                        32765538074
# Máy Ảnh - Quay Phim (Digital Cameras)                      23141146044
# Hàng Tiêu Dùng - Thực Phẩm (Consumer Goods - Fo...          1420559208
# Phụ Kiện - Thiết Bị Số (Accessories - Digital D...         70997879707
# ...
